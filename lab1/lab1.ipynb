# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json("/home/vitquay1708/Study_Space/NLP/lab1/c4-train.00000-of-01024-30K.json.gz", lines=True)
df.head(5)
# Out:
#                                                 text  \
# 0  Beginners BBQ Class Taking Place in Missoula!\...
# 1  Discussion in 'Mac OS X Lion (10.7)' started b...
# 2  Foil plaid lycra and spandex shortall with met...
# 3  How many backlinks per day for new site?\nDisc...
# 4  The Denver Board of Education opened the 2017-...
#
#                   timestamp                                                url
# 0 2019-04-25 12:57:54+00:00  https://klyq.com/beginners-bbq-class-taking-pl...
# 1 2019-04-21 10:07:13+00:00  https://forums.macrumors.com/threads/restore-f...
# 2 2019-04-25 10:40:23+00:00  https://awishcometrue.com/Catalogs/Clearance/T...
# 3 2019-04-21 12:46:19+00:00  https://www.blackhatworld.com/seo/how-many-bac...
# 4 2019-04-20 14:33:21+00:00              http://bond.dpsk12.org/category/news/

# %%
import TfIdfVectorizer

vectorizer = TfIdfVectorizer(df)
vectorizer
